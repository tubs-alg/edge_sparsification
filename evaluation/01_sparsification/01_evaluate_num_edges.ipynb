# %% [markdown]
# # Getting some general information on the sparsified graphs

# %%
import pandas as pd
import seaborn as sns
sns.set_theme()
import matplotlib.pyplot as plt
sns.set_theme()
plt.rcParams.update({'figure.max_open_warning': 0
                    ,"text.usetex": True
                    ,"font.family": "serif"
                    })
sns.set_palette("tab10")
PAPER_WIDTH = 10

# %%
data = pd.read_json("./00_sparsification_data.json.zip")

# %%
data
# Out:
#         num_vertices                     instance  \
# 0                 48                   att48_48_0
# 1                 48                   att48_48_0
# 2                 48                   att48_48_0
# 3                 48                   att48_48_0
# 4                 48                   att48_48_0
# ...              ...                          ...
# 443017           520  20210530_uniform_real_520_8
# 443018           520  20210530_uniform_real_520_8
# 443019           520  20210530_uniform_real_520_8
# 443020           520  20210530_uniform_real_520_8
# 443021           520  20210530_uniform_real_520_8
#
#                                                      id_x  num_edges  \
# 0                                    att48_48_0_onion-1-2        144
# 1                                    att48_48_0_wspd0-4-1        357
# 2                                    att48_48_0_wspd0-2-1        213
# 3                                      att48_48_0_wspd4-3        516
# 4                                    att48_48_0_wspd0-3-2          0
# ...                                                   ...        ...
# 443017              20210530_uniform_real_520_8_delaunayT       1540
# 443018                 20210530_uniform_real_520_8_yao6-0       1482
# 443019  20210530_uniform_real_520_8_relativeNeighborho...        652
# 443020              20210530_uniform_real_520_8_onion-2-1       1557
# 443021                20210530_uniform_real_520_8_onion-0      10225
#
#        GRB_OUT_BestBd GRB_OUT_Incumbent  max_stretch  \
# 0                None              None     3.965147
# 1                None              None     1.231905
# 2                None              None     1.560013
# 3                None              None     1.522355
# 4                None              None          NaN
# ...               ...               ...          ...
# 443017           None              None     1.392625
# 443018           None              None     1.875237
# 443019           None              None     4.461242
# 443020           None              None   117.974290
# 443021           None              None    22.491349
#
#                                                filename_x  \
# 0                               att48_48_0_onion-1-2.json
# 1                               att48_48_0_wspd0-4-1.json
# 2                               att48_48_0_wspd0-2-1.json
# 3                                 att48_48_0_wspd4-3.json
# 4                               att48_48_0_wspd0-3-2.json
# ...                                                   ...
# 443017         20210530_uniform_real_520_8_delaunayT.json
# 443018            20210530_uniform_real_520_8_yao6-0.json
# 443019  20210530_uniform_real_520_8_relativeNeighborho...
# 443020         20210530_uniform_real_520_8_onion-2-1.json
# 443021           20210530_uniform_real_520_8_onion-0.json
#
#          sparsification_technique  stretch_median GRB_OUT_Time          type  \
# 0                       onion-1-2        1.038839         None        TSPLIB
# 1                       wspd0-4-1        1.002591         None        TSPLIB
# 2                       wspd0-2-1        1.018751         None        TSPLIB
# 3                         wspd4-3        1.000056         None        TSPLIB
# 4                       wspd0-3-2             NaN         None        TSPLIB
# ...                           ...             ...          ...           ...
# 443017                  delaunayT             NaN         None  uniform_real
# 443018                     yao6-0        1.065131         None  uniform_real
# 443019  relativeNeighborhoodGraph        1.276160         None  uniform_real
# 443020                  onion-2-1        1.762482         None  uniform_real
# 443021                    onion-0        1.167813         None  uniform_real
#
#                               filename_y  size                         id_y
# 0                        att48_48_0.json    48                   att48_48_0
# 1                        att48_48_0.json    48                   att48_48_0
# 2                        att48_48_0.json    48                   att48_48_0
# 3                        att48_48_0.json    48                   att48_48_0
# 4                        att48_48_0.json    48                   att48_48_0
# ...                                  ...   ...                          ...
# 443017  20210530_uniform_real_520_8.json   520  20210530_uniform_real_520_8
# 443018  20210530_uniform_real_520_8.json   520  20210530_uniform_real_520_8
# 443019  20210530_uniform_real_520_8.json   520  20210530_uniform_real_520_8
# 443020  20210530_uniform_real_520_8.json   520  20210530_uniform_real_520_8
# 443021  20210530_uniform_real_520_8.json   520  20210530_uniform_real_520_8
#
# [443022 rows x 15 columns]

# %%
data["type"].unique()
# Out:
# array(['TSPLIB', 'image_brightness', 'uniform_real', 'normal',
#        'uniform_int', 'image_edge'], dtype=object)

# %%
t= data.drop_duplicates(subset=["filename_y", "type", "num_vertices"]).copy()
t["type"] = t["type"].replace({"TSPLIB_subset": "TSPLIB", "uniform_int": "uniform", "uniform_real": "uniform", "image_edge": "image", "image_brightness": "image"})
#sns.histplot(t, x="num_vertices", hue="type", y="type", element="poly",
#    stat="density", common_norm=False, fill=False, legend=False)

sns.histplot(
    t, x="num_vertices", hue="type", 
    #element="poly",stat="density", common_norm=False, fill=False
    multiple="dodge", shrink=.8
)
plt.show()

# %%
data["sparsification_technique"].unique()
# Out:
# array(['onion-1-2', 'wspd0-4-1', 'wspd0-2-1', 'wspd4-3', 'wspd0-3-2',
#        'yao6-1', 'gabrielGraph', 'wspd7-3', 'complete', 'wspd6-2',
#        'greedy1.5', 'yao12-2', 'yao24-2', 'wspd2-0', 'wspd4-0', 'greedy2',
#        'onion-1-1', 'wspd0-1-3', 'onion-2-2', 'wspd4-2', 'yao18-0',
#        'onion-1-3', 'theta18-2', 'yao18-2', 'wspd2-3', 'wspd0-2-3',
#        'wspd0-1-0', 'yao18-1', 'yao12-0', 'wspd0-1-1', 'onion-2-3',
#        'wspd7-2', 'wspd5-1', 'yao6-2', 'onion-2-1', 'wspd6-0', 'wspd8-2',
#        'wspd5-3', 'wspd7-1', 'yao12-1', 'theta6-0', 'theta12-0',
#        'wspd4-1', 'wspd7-0', 'wspd3-0', 'theta24-1', 'mwT', 'wspd0-3-0',
#        'theta24-2', 'wspd0-4-0', 'theta18-0', 'wspd5-2', 'yao24-1',
#        'wspd8-1', 'wspd8-0', 'wspd0-4-2', 'yao6-0', 'wspd0-1-2',
#        'wspd0-3-1', 'wspd3-3', 'wspd3-2', 'theta24-0', 'greedyT',
#        'wspd6-1', 'wspd2-1', 'onion-0', 'theta6-1',
#        'relativeNeighborhoodGraph', 'wspd2-2', 'wspd3-1', 'theta12-2',
#        'wspd0-4-3', 'delaunayT', 'wspd6-3', 'theta12-1', 'theta18-1',
#        'wspd5-0', 'wspd0-2-2', 'theta6-2', 'wspd0-2-0', 'yao24-0',
#        'wspd0-3-3', 'wspd8-3', 'wspd1.5-1', 'greedy1.3', 'wspd1.5-3'],
#       dtype=object)

# %%
angdist = ["complete", "delaunayT", "wspd2-1", "yao6-2"]
angtsp = ["complete", "onion-0", "onion-1-1", "wspd7-3", "yao6-2",  "wspd2-1", "wspd2-3",]
maxarea = ["complete", "theta12-2", "wspd2-3", "yao12-2"]
minarea= ["complete", "theta12-2", "wspd2-3", "yao12-2"]
mpp =["complete", "delaunayT", "greedyT", "mwT", "yao6-2"]
selection = list(set(angdist + angtsp +maxarea+minarea+mpp))
#selection = ['complete', 'mwT', 'greedyT', 'onion-0','wspd2-1' , 'yao6-2', ]
sorted(selection)
# Out:
# ['complete',
#  'delaunayT',
#  'greedyT',
#  'mwT',
#  'onion-0',
#  'onion-1-1',
#  'theta12-2',
#  'wspd2-1',
#  'wspd2-3',
#  'wspd7-3',
#  'yao12-2',
#  'yao6-2']

# %%
t = data[data["sparsification_technique"].isin(selection)].copy()
t["sparsification_technique"].replace({'delaunayT': "triangulation",
 'greedyT': "triangulation",
 'mwT': "triangulation"}, inplace=True)
t["sparsification_technique"].replace({'theta12-2': "cone(12)",
 'yao12-2': "cone(12)",
 'yao6-2': "cone(6)"}, inplace=True)
t["num_vertices"] = t["num_vertices"].apply(lambda x: round(x/10)*10)
t=t[t["num_vertices"]<=500]
t = t.groupby(["num_vertices", "sparsification_technique"])[["num_edges"]].mean().reset_index()

# %%
order =  {  'complete': 0,
 'triangulation': 1,
 'onion-0': 2,
 'onion-1-1': 3,
 'cone(12)': 5,
 'wspd2-1': 6,
 'wspd2-3': 7,
 'wspd7-3': 8,
 'cone(6)' : 4,
 }
t["order"]=t["sparsification_technique"].apply(lambda x: order[x])
t.sort_values(by=["order","num_vertices"], inplace=True)

# %%
techniques = t["sparsification_technique"].unique()
palette = sns.color_palette("tab10")
colors = {
   'complete': palette[0],
 'triangulation': palette[1],
 'onion-0': palette[2],
 'onion-1-1': palette[2],
 'cone(12)': palette[3],
 'wspd2-1': palette[4],
 'wspd2-3': palette[4],
 'wspd7-3': palette[4],
 'cone(6)' : palette[3],
}
palette = sns.color_palette([colors[t] for t in techniques])
line_styles = ['-', ":", "--", "-."]
styles = {
       'complete': line_styles[0],
 'triangulation': line_styles[0],
 'onion-0': line_styles[0],
 'onion-1-1': line_styles[1],
 'cone(12)': line_styles[1],
 'wspd2-1': line_styles[0],
 'wspd2-3': line_styles[1],
 'wspd7-3': line_styles[2],
 'cone(6)' : line_styles[0],
}
line_styles = [styles[t] for t in techniques]

# %%
plt.figure(figsize=(0.6*PAPER_WIDTH, 4))
t["technique"]=t["sparsification_technique"]

ax = sns.lineplot(data=t, x="num_vertices", y="num_edges", hue="technique", style="technique", palette=palette)
for i, l in enumerate(ax.lines):
    l.set_linestyle(line_styles[i%len(line_styles)])
ax.legend(title=None)
plt.xlabel("Number of vertices")
plt.ylabel("Number of edges")
plt.tight_layout()
plt.savefig("output/num_edges_lineplot.pdf")
plt.show()

# %%
t
# Out:
#      num_vertices sparsification_technique     num_edges  order technique
# 0               0                 complete     10.000000      0  complete
# 9              10                 complete     47.857671      0  complete
# 18             20                 complete    196.047445      0  complete
# 27             30                 complete    435.000000      0  complete
# 36             40                 complete    788.543046      0  complete
# ..            ...                      ...           ...    ...       ...
# 422           460                  wspd7-3   9274.900000      8   wspd7-3
# 431           470                  wspd7-3   9490.060000      8   wspd7-3
# 440           480                  wspd7-3   9768.946667      8   wspd7-3
# 449           490                  wspd7-3  10065.823529      8   wspd7-3
# 458           500                  wspd7-3  10460.754545      8   wspd7-3
#
# [459 rows x 5 columns]

# %%
plt.figure(figsize=(0.4*PAPER_WIDTH, 4))
ns = [20, 100, 400]
t_ = t[t["num_vertices"].isin(ns)].copy()

t_.rename(columns={"num_vertices": "n", "num_edges": "m"}, inplace=True)
t_["complete"]=0
for n in ns:
    t_.loc[t_["n"]==n, "complete"]=t_[t_["n"]==n]["m"].max()
t_ = t_[t_["technique"]!="complete"].copy()
t_["x"]=100*t_["m"]/t_["complete"]
t_ = t_.groupby(["n", "technique"])[["x", "order"]].mean().reset_index()
t_.sort_values(by="order", inplace=True)
sns.barplot(data=t_, y="technique", x="x", hue="n")
plt.legend(title="Vertices")
plt.xlabel("Percentage of edges (\%)")
plt.ylabel("Sparsification")
plt.xlim(0, 100)
plt.tight_layout()
plt.savefig("output/num_edges_barplot.pdf")
plt.show()
