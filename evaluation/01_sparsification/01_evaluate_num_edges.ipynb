# %% [markdown]
# # Getting some general information on the sparsified graphs

# %%
import pandas as pd
import seaborn as sns
sns.set_theme()
import matplotlib.pyplot as plt
sns.set_theme()
plt.rcParams.update({'figure.max_open_warning': 0
                    ,"text.usetex": True
                    ,"font.family": "serif"
                    })
sns.set_palette("tab10")
PAPER_WIDTH = 10

# %%
data = pd.read_json("./00_sparsification_data.json.zip")

# %%
data
# Out:
#                            instance  num_vertices  max_stretch  \
# 0                       ch130_130_0           130     2.395865
# 1                       ch130_130_0           130     2.395865
# 2                       ch130_130_0           130     1.434657
# 3                       ch130_130_0           130     1.434657
# 4                       ch130_130_0           130     1.434657
# ...                             ...           ...          ...
# 270308  20210530_uniform_real_520_3           520     1.000000
# 270309  20210530_uniform_real_520_3           520   390.818784
# 270310  20210530_uniform_real_520_3           520     1.328949
# 270311  20210530_uniform_real_520_3           520     1.952459
# 270312  20210530_uniform_real_520_3           520     1.388454
#
#         stretch_median                                  filename_x  num_edges  \
# 0             1.028483                  ch130_130_0_wspd0-3-0.json        994
# 1             1.028483                  ch130_130_0_wspd0-3-0.json        994
# 2                  NaN                        ch130_130_0_mwT.json        377
# 3                  NaN                        ch130_130_0_mwT.json        377
# 4                  NaN                    ch130_130_0_greedyT.json        377
# ...                ...                                         ...        ...
# 270308             NaN   20210530_uniform_real_520_3_complete.json     134940
# 270309        1.927075  20210530_uniform_real_520_3_onion-2-1.json       1553
# 270310        1.000215    20210530_uniform_real_520_3_wspd2-3.json      28632
# 270311        1.071832   20210530_uniform_real_520_3_theta6-0.json       1484
# 270312             NaN  20210530_uniform_real_520_3_delaunayT.json       1541
#
#        sparsification_technique                                   id_x  \
# 0                     wspd0-3-0                  ch130_130_0_wspd0-3-0
# 1                     wspd0-3-0                  ch130_130_0_wspd0-3-0
# 2                           mwT                        ch130_130_0_mwT
# 3                           mwT                        ch130_130_0_mwT
# 4                       greedyT                    ch130_130_0_greedyT
# ...                         ...                                    ...
# 270308                 complete   20210530_uniform_real_520_3_complete
# 270309                onion-2-1  20210530_uniform_real_520_3_onion-2-1
# 270310                  wspd2-3    20210530_uniform_real_520_3_wspd2-3
# 270311                 theta6-0   20210530_uniform_real_520_3_theta6-0
# 270312                delaunayT  20210530_uniform_real_520_3_delaunayT
#
#                  type                        filename_y  \
# 0              TSPLIB                  ch130_130_0.json
# 1       TSPLIB_subset                  ch130_130_0.json
# 2              TSPLIB                  ch130_130_0.json
# 3       TSPLIB_subset                  ch130_130_0.json
# 4              TSPLIB                  ch130_130_0.json
# ...               ...                               ...
# 270308   uniform_real  20210530_uniform_real_520_3.json
# 270309   uniform_real  20210530_uniform_real_520_3.json
# 270310   uniform_real  20210530_uniform_real_520_3.json
# 270311   uniform_real  20210530_uniform_real_520_3.json
# 270312   uniform_real  20210530_uniform_real_520_3.json
#
#                                id_y  size
# 0                       ch130_130_0   130
# 1                       ch130_130_0   130
# 2                       ch130_130_0   130
# 3                       ch130_130_0   130
# 4                       ch130_130_0   130
# ...                             ...   ...
# 270308  20210530_uniform_real_520_3   520
# 270309  20210530_uniform_real_520_3   520
# 270310  20210530_uniform_real_520_3   520
# 270311  20210530_uniform_real_520_3   520
# 270312  20210530_uniform_real_520_3   520
#
# [270313 rows x 12 columns]

# %%
data["sparsification_technique"].unique()
# Out:
# array(['wspd0-3-0', 'mwT', 'greedyT', 'onion-1-1', 'onion-2-2',
#        'onion-2-1', 'yao24-2', 'wspd4-0', 'wspd0-2-3', 'greedy2',
#        'theta12-2', 'wspd6-1', 'wspd0-4-2', 'onion-2-3', 'wspd4-3',
#        'wspd8-1', 'wspd0-2-0', 'wspd5-3', 'theta24-1', 'wspd0-1-0',
#        'wspd0-4-3', 'delaunayT', 'wspd8-0', 'yao18-1', 'wspd6-0',
#        'wspd5-2', 'wspd8-3', 'wspd7-1', 'onion-1-2', 'wspd3-2',
#        'complete', 'gabrielGraph', 'wspd4-2', 'yao12-2', 'wspd0-2-2',
#        'yao6-0', 'theta24-2', 'wspd2-2', 'wspd5-0', 'yao18-0', 'wspd3-1',
#        'wspd2-3', 'yao12-0', 'wspd7-0', 'wspd7-2', 'wspd0-1-2', 'wspd8-2',
#        'wspd0-1-1', 'wspd5-1', 'theta12-1', 'theta6-2', 'wspd6-2',
#        'onion-0', 'theta12-0', 'wspd2-1', 'wspd0-4-0', 'wspd0-2-1',
#        'wspd0-3-1', 'yao6-1', 'theta18-1', 'wspd3-3', 'yao18-2',
#        'wspd2-0', 'relativeNeighborhoodGraph', 'greedy1.5', 'yao12-1',
#        'wspd0-1-3', 'wspd0-4-1', 'wspd6-3', 'wspd7-3', 'theta6-0',
#        'wspd0-3-2', 'onion-1-3', 'theta18-2', 'yao24-0', 'wspd4-1',
#        'theta24-0', 'theta6-1', 'wspd3-0', 'theta18-0', 'wspd0-3-3',
#        'yao6-2', 'yao24-1', 'greedy1.3', 'wspd1.5-1', 'wspd1.5-3'],
#       dtype=object)

# %%
angdist = ["complete", "delaunayT", "wspd2-1", "yao6-2"]
angtsp = ["complete", "onion-0", "onion-1-1", "wspd7-3", "yao6-2",  "wspd2-1", "wspd2-3",]
maxarea = ["complete", "theta12-2", "wspd2-3", "yao12-2"]
minarea= ["complete", "theta12-2", "wspd2-3", "yao12-2"]
mpp =["complete", "delaunayT", "greedyT", "mwT", "yao6-2"]
selection = list(set(angdist + angtsp +maxarea+minarea+mpp))
#selection = ['complete', 'mwT', 'greedyT', 'onion-0','wspd2-1' , 'yao6-2', ]
sorted(selection)
# Out:
# ['complete',
#  'delaunayT',
#  'greedyT',
#  'mwT',
#  'onion-0',
#  'onion-1-1',
#  'theta12-2',
#  'wspd2-1',
#  'wspd2-3',
#  'wspd7-3',
#  'yao12-2',
#  'yao6-2']

# %%
t = data[data["sparsification_technique"].isin(selection)].copy()
t["sparsification_technique"].replace({'delaunayT': "triangulation",
 'greedyT': "triangulation",
 'mwT': "triangulation"}, inplace=True)
t["sparsification_technique"].replace({'theta12-2': "cone(12)",
 'yao12-2': "cone(12)",
 'yao6-2': "cone(6)"}, inplace=True)
t["num_vertices"] = t["num_vertices"].apply(lambda x: round(x/10)*10)
t=t[t["num_vertices"]<=500]
t = t.groupby(["num_vertices", "sparsification_technique"])[["num_edges"]].mean().reset_index()

# %%
order =  {  'complete': 0,
 'triangulation': 1,
 'onion-0': 2,
 'onion-1-1': 3,
 'cone(12)': 5,
 'wspd2-1': 6,
 'wspd2-3': 7,
 'wspd7-3': 8,
 'cone(6)' : 4,
 }
t["order"]=t["sparsification_technique"].apply(lambda x: order[x])
t.sort_values(by=["order","num_vertices"], inplace=True)

# %%
techniques = t["sparsification_technique"].unique()
palette = sns.color_palette("tab10")
colors = {
   'complete': palette[0],
 'triangulation': palette[1],
 'onion-0': palette[2],
 'onion-1-1': palette[2],
 'cone(12)': palette[3],
 'wspd2-1': palette[4],
 'wspd2-3': palette[4],
 'wspd7-3': palette[4],
 'cone(6)' : palette[3],
}
palette = sns.color_palette([colors[t] for t in techniques])
line_styles = ['-', ":", "--", "-."]
styles = {
       'complete': line_styles[0],
 'triangulation': line_styles[0],
 'onion-0': line_styles[0],
 'onion-1-1': line_styles[1],
 'cone(12)': line_styles[1],
 'wspd2-1': line_styles[0],
 'wspd2-3': line_styles[1],
 'wspd7-3': line_styles[2],
 'cone(6)' : line_styles[0],
}
line_styles = [styles[t] for t in techniques]

# %%
plt.figure(figsize=(0.6*PAPER_WIDTH, 4))
t["technique"]=t["sparsification_technique"]

ax = sns.lineplot(data=t, x="num_vertices", y="num_edges", hue="technique", style="technique", palette=palette)
for i, l in enumerate(ax.lines):
    l.set_linestyle(line_styles[i%len(line_styles)])
ax.legend(title=None)
plt.xlabel("Number of vertices")
plt.ylabel("Number of edges")
plt.tight_layout()
plt.savefig("output/num_edges_lineplot.pdf")
plt.show()

# %%
t
# Out:
#      num_vertices sparsification_technique     num_edges  order technique
# 0               0                 complete     10.000000      0  complete
# 9              10                 complete     48.085828      0  complete
# 18             20                 complete    195.656695      0  complete
# 27             30                 complete    435.000000      0  complete
# 36             40                 complete    788.681319      0  complete
# ..            ...                      ...           ...    ...       ...
# 422           460                  wspd7-3  10294.500000      8   wspd7-3
# 431           470                  wspd7-3  10521.566667      8   wspd7-3
# 440           480                  wspd7-3  10843.366667      8   wspd7-3
# 449           490                  wspd7-3  11192.516129      8   wspd7-3
# 458           500                  wspd7-3  11508.757143      8   wspd7-3
#
# [459 rows x 5 columns]

# %%
plt.figure(figsize=(0.4*PAPER_WIDTH, 4))
ns = [20, 100, 400]
t_ = t[t["num_vertices"].isin(ns)].copy()

t_.rename(columns={"num_vertices": "n", "num_edges": "m"}, inplace=True)
t_["complete"]=0
for n in ns:
    t_.loc[t_["n"]==n, "complete"]=t_[t_["n"]==n]["m"].max()
t_ = t_[t_["technique"]!="complete"].copy()
t_["x"]=100*t_["m"]/t_["complete"]
t_ = t_.groupby(["n", "technique"])[["x", "order"]].mean().reset_index()
t_.sort_values(by="order", inplace=True)
sns.barplot(data=t_, y="technique", x="x", hue="n")
plt.legend(title="Vertices")
plt.xlabel("Percentage of edges (\%)")
plt.ylabel("Sparsification")
plt.xlim(0, 100)
plt.tight_layout()
plt.savefig("output/num_edges_barplot.pdf")
plt.show()
